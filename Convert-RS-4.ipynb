# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mlb
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
import math
warnings.filterwarnings('ignore')
sns.set(style="whitegrid")

#palette : {deep, muted, pastel, dark, bright, colorblind}
sns.set_color_codes("dark")

# %%
def convert_existing_pca_rs(input_rs, cookbook):
    """ This function takes existing PCA RS and outputs the new RS format."""
    
    req_set = set()

    pca_filter = input_rs['Req Source'] == 'PCA'

    input_rs = input_rs[pca_filter].copy()
    
    for i in input_rs['Req nr']:
        #print i
        #if "H" not in i:
        req_set.add(i)
            
    #print req_set
        
    
    cb_reqs = pd.Series(cookbook['Req nr'], copy=True)
    
    #cookbook['Req nr'].replace(regex=True,inplace=True,to_replace=r'H',value=r'')
    #cookbook['Req nr'].replace(regex=True,inplace=True,to_replace=r'V',value=r'')
    #cookbook['Req nr'].replace(regex=True,inplace=True,to_replace=r'a',value=r'')
    #cookbook['Req nr'].replace(regex=True,inplace=True,to_replace=r'b',value=r'')
          
    compliancy_list = {}
    i = 0
    for x in input_rs['Req nr']:
        compliancy_list.update({x:list(input_rs.loc[input_rs['Req nr'] == x, 'Compliance Assessment'])[0]})
        i = i + 1
    
    feedback_list = {}
    i = 0
    for x in input_rs['Req nr']:
        feedback_list.update({x:list(input_rs.loc[input_rs['Req nr'] == x, 'Required additional controls/Compliance Feedback'])[0]})
        i = i + 1
    

    response_list = {}
    i = 0
    for x in input_rs['Req nr']:
        response_list.update({x:input_rs.loc[input_rs['Req nr'] == x, 'Response']})
        i = i + 1
    
    #print '~~~~~~~~~~~~~~~'
    #print response_list
        
    remref_list = {}
    i = 0
    for x in input_rs['Req nr']:
        remref_list.update({x:list(input_rs.loc[input_rs['Req nr'] == x, 'Remediation Project Ref'])[0]})
        i = i + 1
    
    res_comments_list = {}
    i = 0
    for x in input_rs['Req nr']:
        res_comments_list.update({x:list(input_rs.loc[input_rs['Req nr'] == x, 'Response Comments'])[0]})
        i = i + 1
    
    compliancy_series = []
    feedback_series = []
    response_series = []
    remref_series = []
    res_comments_series = []
    
    #print response_list

    cookbook['Compliance Assessment'] = ''
    cookbook['Required additional controls/Compliance Feedback'] = ''
    cookbook['Response'] = ''
    cookbook['Remediation Project Ref'] = ''
    cookbook['Response Comments'] = ''
    
    #print req_set

    #cookbook['Req nr'] = cb_reqs

    
    for i in range(0,107):
        if cookbook.iloc[i]['Req nr'] in req_set:
            print cookbook.iloc[i]['Req nr']
            if cookbook.iloc[i]['Req nr'] == '12H':
                print response_list[cookbook.iloc[i]['Req nr']]
                
            compliancy_series.append(compliancy_list[cookbook.iloc[i]['Req nr']])
            feedback_series.append(feedback_list[cookbook.iloc[i]['Req nr']])
            response_series.append(response_list[cookbook.iloc[i]['Req nr']])
            remref_series.append(remref_list[cookbook.iloc[i]['Req nr']])
            res_comments_series.append(res_comments_list[cookbook.iloc[i]['Req nr']])
            
            cookbook.loc[cookbook['Req nr'] == cookbook.iloc[i]['Req nr'], 'Response'] = response_list[cookbook.iloc[i]['Req nr']]
            cookbook.loc[cookbook['Req nr'] == cookbook.iloc[i]['Req nr'], 'Compliance Assessment'] = compliancy_list[cookbook.iloc[i]['Req nr']]
            cookbook.loc[cookbook['Req nr'] == cookbook.iloc[i]['Req nr'], 'Remediation Project Ref'] = remref_list[cookbook.iloc[i]['Req nr']]
            cookbook.loc[cookbook['Req nr'] == cookbook.iloc[i]['Req nr'], 'Response Comments'] = res_comments_list[cookbook.iloc[i]['Req nr']]
            cookbook.loc[cookbook['Req nr'] == cookbook.iloc[i]['Req nr'], 'Required additional controls/Compliance Feedback'] = feedback_list[cookbook.iloc[i]['Req nr']]
        else:
            compliancy_series.append(float('nan'))
            feedback_series.append(float('nan'))
            response_series.append(float('nan'))
            remref_series.append(float('nan'))
            res_comments_series.append(float('nan'))

    #print '###########################'
    #print cookbook.iloc[5]['Req nr']
    
    #print len(cb_reqs)
    #print len(response_series)
    req_list = list(cb_reqs)
    #print len(req_list)
    #print req_list
    resp_df = pd.DataFrame({'Req nr':list(cb_reqs), 
                            'Response':response_series, 
                            'Compliance Assessment':compliancy_series,
                            'Remediation Project Ref':remref_series,
                            'Response Comments':res_comments_series,
                            'Required additional controls/Compliance Feedback':feedback_series})
    #print resp_df
    #print '###########################'
    
    
    cookbook.sort_values(by=['Compliance Assessment','Req nr'],ascending=True, inplace=True)
    
    cookbook.rename(columns={'Cookbook RS Statements':'GDPR Requirement Specification',
                             'Privacy Requirement':'Requirement',
                             'People+Process Applicable':'People/Process Applicability',
                             'Technology  (& Design) Applicable':'Technology/Design Applicability'}, inplace=True)
    
    comliancy_filter = cookbook['Compliance Assessment'] != float('nan')
        
    return cookbook[comliancy_filter]

# %%
def convert_existing_sca_rs(input_rs, cookbook):
    """ This function takes existing SCA RS and outputs the new RS format."""
    
    req_set = set()

    sca_filter = input_rs['Req Source'] == 'SCA'

    input_rs = input_rs[sca_filter].copy()
    
    for i in input_rs['Req nr']:
        #print i
        req_set.add(i)
        
    
    cb_reqs = pd.Series(cookbook['RS Reference Number'], copy=True)
    
    compliancy_list = {}
    i = 0
    for x in input_rs['Req nr']:
        compliancy_list.update({x:input_rs.iloc[i]['Compliance Assessment']})
        i = i + 1
    
    feedback_list = {}
    i = 0
    for x in input_rs['Req nr']:
        feedback_list.update({x:input_rs.iloc[i]['Required additional controls/Compliance Feedback']})
        i = i + 1
    

    response_list = {}
    i = 0
    for x in input_rs['Req nr']:
        response_list.update({x:input_rs.iloc[i]['Response']})
        i = i + 1
        
    remref_list = {}
    i = 0
    for x in input_rs['Req nr']:
        remref_list.update({x:input_rs.iloc[i]['Remediation Project Ref']})
        i = i + 1
    
    res_comments_list = {}
    i = 0
    for x in input_rs['Req nr']:
        res_comments_list.update({x:input_rs.iloc[i]['Response Comments']})
        i = i + 1
    
    compliancy_series = []
    feedback_series = []
    response_series = []
    remref_series = []
    res_comments_series = []
    
    for i in range(0,15):
        if cookbook.iloc[i]['RS Reference Number'][10:-2] in req_set:
            compliancy_series.append(compliancy_list[cookbook.iloc[i]['RS Reference Number'][10:-2]])
            feedback_series.append(feedback_list[cookbook.iloc[i]['RS Reference Number'][10:-2]])
            response_series.append(response_list[cookbook.iloc[i]['RS Reference Number'][10:-2]])
            remref_series.append(remref_list[cookbook.iloc[i]['RS Reference Number'][10:-2]])
            res_comments_series.append(res_comments_list[cookbook.iloc[i]['RS Reference Number'][10:-2]])
        else:
            compliancy_series.append(float('nan'))
            feedback_series.append(float('nan'))
            response_series.append(float('nan'))
            remref_series.append(float('nan'))
            res_comments_series.append(float('nan'))
            
    
    resp_df = pd.DataFrame({'Req nr':list(cb_reqs), 
                            'Response':response_series, 
                            'Compliance Assessment':compliancy_series,
                            'Remediation Project Ref':remref_series,
                            'Response Comments':res_comments_series,
                            'Required additional controls/Compliance Feedback':feedback_series})
    #print resp_df
    #print '###########################'
    
    cookbook['Response'] = resp_df['Response']
    cookbook['Compliance Assessment'] = resp_df['Compliance Assessment']
    cookbook['Remediation Project Ref'] = resp_df['Remediation Project Ref']
    cookbook['Response Comments'] = resp_df['Response Comments']
    cookbook['Required additional controls/Compliance Feedback'] = resp_df['Required additional controls/Compliance Feedback']
    
    cookbook.sort_values(by=['Compliance Assessment'],ascending=True, inplace=True)
    
    cookbook['Req nr'] = cb_reqs
    
    cookbook.rename(columns={'Cookbook RS Statements':'GDPR Requirement Specification',
                             'Privacy Requirement':'Requirement',
                             'People+Process Applicable':'People/Process Applicability',
                             'Technology  (& Design) Applicable':'Technology/Design Applicability'}, inplace=True)
    
    comliancy_filter = cookbook['Compliance Assessment'] != float('nan')
        
    return cookbook[comliancy_filter]

# %%
os.chdir('/home/andy/dev/notebooks/Transfer-RS-Feedback/RS_FEEDBACK/IoT')

#OUTPUT_BASE_PATH = '/home/andy/dev/notebooks/Transfer-RS-Feedback/output_rs/'
OUTPUT_BASE_PATH = '/home/andy/dev/GDPR/converted_rs/'
OUT_FILENAME = 'outfile.xlsx'

COOKBOOK_FILE = '/home/andy/dev/GDPR/inputdata/PCA SCA Cookbook Mapping_3.4.xlsx'

cookbook = pd.read_excel(COOKBOOK_FILE, 
                         sheet_name='PCA',
                         skiprows=1)

cookbook_sca = pd.read_excel(COOKBOOK_FILE, 
                         sheet_name='SCA',
                         skiprows=1)

first = True
new_rs_sheets = {}

for filename in os.listdir(os.getcwd()):
    print filename
    output_writer = pd.ExcelWriter(OUTPUT_BASE_PATH + 'CONVERTED-PCA-' + filename[:14] + '.xlsx')

    df = pd.read_excel(filename, sheet_name=None)
    
    sheet_names = df.keys()
    sheets = sheet_names[4:-1]
    #print sheets

    for sh in sheets:
        print sh
        if sh == u'PII Data Record': # this is a bug? Don't know why I need this.  For some reason the last sheet comes through.
            continue
        #new_rs_sheets.update({filename: dict({sh: convert_rs(df[sh], cookbook)})})
        
        print df[sh][['Req nr','Response']]
        out_df = convert_existing_pca_rs(df[sh], cookbook)
        
        out_df.to_excel(output_writer,sh)
        
    output_writer.save()
# Out:
# GDPR-RS-EPS094-MACS-V4.0 MAPPED.xlsx
# A - Portal
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2        2H  Acknowledged
# 3       31H  Acknowledged
# 4       49H  Acknowledged
# 5       49V  Acknowledged
# 6       51V  Acknowledged
# 7       53V     Completed
# 8       57H  Acknowledged
# 9       57V  Acknowledged
# 10      58H  Acknowledged
# 11      60H  Acknowledged
# 12      64H  Acknowledged
# 13      74V  Acknowledged
# 14      75H  Acknowledged
# 15      76H  Acknowledged
# 16      76V  Acknowledged
# 17      66H  Acknowledged
# 18      67H  Acknowledged
# 19      69H  Acknowledged
# 20      69V  Acknowledged
# 21      70V  Acknowledged
# 22  9.2.6-A  Acknowledged
# 23  9.2.1-A  Acknowledged
# 24    9.2.2  Acknowledged
# 25    9.2.3  Acknowledged
# 26    9.2.5  Acknowledged
# 27  9.2.6-B  Acknowledged
# 28    9.4.1  Acknowledged
# 29    9.4.2  Acknowledged
# 30   12.4.1  Acknowledged
# 31   12.4.3  Acknowledged
# 32   13.2.1  Acknowledged
# 2H
# 4H
# 31H
# 49H
# 49V
# 51V
# 53V
# 57H
# 57V
# 58H
# 60H
# 64H
# 66H
# 67H
# 69H
# 69V
# 70V
# 74V
# 75H
# 76H
# 76V
# B - Business Logic
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2        2H  Acknowledged
# 3       31H  Acknowledged
# 4       49H  Acknowledged
# 5       49V  Acknowledged
# 6       51V  Acknowledged
# 7       53V     Completed
# 8       57H  Acknowledged
# 9       57V  Acknowledged
# 10      58H  Acknowledged
# 11      60H  Acknowledged
# 12      64H  Acknowledged
# 13      74V  Acknowledged
# 14      75H  Acknowledged
# 15      76H  Acknowledged
# 16      76V  Acknowledged
# 17      66H  Acknowledged
# 18      67H  Acknowledged
# 19      69H  Acknowledged
# 20      69V  Acknowledged
# 21      70V  Acknowledged
# 22  9.2.6-A  Acknowledged
# 23  9.2.1-A  Acknowledged
# 24    9.2.2  Acknowledged
# 25    9.2.3  Acknowledged
# 26    9.2.5  Acknowledged
# 27  9.2.6-B  Acknowledged
# 28    9.4.1  Acknowledged
# 29    9.4.2  Acknowledged
# 30   12.4.1  Acknowledged
# 31   12.4.3  Acknowledged
# 32   13.2.1  Acknowledged
# 4H
# 2H
# 31H
# 49H
# 49V
# 51V
# 53V
# 57H
# 57V
# 58H
# 60H
# 64H
# 74V
# 75H
# 76H
# 76V
# 66H
# 67H
# 69H
# 69V
# 70V
# C - Database
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2        2H  Acknowledged
# 3       31H  Acknowledged
# 4       49H  Acknowledged
# 5       49V  Acknowledged
# 6       51V  Acknowledged
# 7       53V     Completed
# 8       57H  Acknowledged
# 9       57V  Acknowledged
# 10      58H  Acknowledged
# 11      60H  Acknowledged
# 12      64H  Acknowledged
# 13      74V  Acknowledged
# 14      75H  Acknowledged
# 15      76H  Acknowledged
# 16      76V  Acknowledged
# 17      66H  Acknowledged
# 18      67H  Acknowledged
# 19      69H  Acknowledged
# 20      69V  Acknowledged
# 21      70V  Acknowledged
# 22  9.2.6-A  Acknowledged
# 23  9.2.1-A  Acknowledged
# 24    9.2.2  Acknowledged
# 25    9.2.3  Acknowledged
# 26    9.2.5  Acknowledged
# 27  9.2.6-B  Acknowledged
# 28    9.4.1  Acknowledged
# 29    9.4.2  Acknowledged
# 30   12.4.1  Acknowledged
# 31   12.4.3  Acknowledged
# 32   13.2.1  Acknowledged
# 4H
# 2H
# 31H
# 49H
# 49V
# 51V
# 53V
# 57H
# 57V
# 58H
# 60H
# 64H
# 74V
# 75H
# 76H
# 76V
# 66H
# 67H
# 69H
# 69V
# 70V
# GDPR-RS-EPS094-MACS-V4.0 RELEASED -- AS Reviewed 18.04.2018.xlsx
# A - Portal
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2        2H  Acknowledged
# 3       31H  Acknowledged
# 4       49H  Acknowledged
# 5       49V  Acknowledged
# 6       51V  Acknowledged
# 7       53V     Completed
# 8       57H  Acknowledged
# 9       57V  Acknowledged
# 10      58H  Acknowledged
# 11      60H  Acknowledged
# 12      64H  Acknowledged
# 13      74V  Acknowledged
# 14      75H  Acknowledged
# 15      76H  Acknowledged
# 16      76V  Acknowledged
# 17      66H  Acknowledged
# 18      67H  Acknowledged
# 19      69H  Acknowledged
# 20      69V  Acknowledged
# 21      70V  Acknowledged
# 22  9.2.6-A  Acknowledged
# 23  9.2.1-A  Acknowledged
# 24    9.2.2  Acknowledged
# 25    9.2.3  Acknowledged
# 26    9.2.5  Acknowledged
# 27  9.2.6-B  Acknowledged
# 28    9.4.1  Acknowledged
# 29    9.4.2  Acknowledged
# 30   12.4.1  Acknowledged
# 31   12.4.3  Acknowledged
# 32   13.2.1  Acknowledged
# 4H
# 2H
# 31H
# 49H
# 49V
# 51V
# 53V
# 57H
# 57V
# 58H
# 60H
# 64H
# 74V
# 75H
# 76H
# 76V
# 66H
# 67H
# 69H
# 69V
# 70V
# B - Business Logic
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2        2H  Acknowledged
# 3       31H  Acknowledged
# 4       49H  Acknowledged
# 5       49V  Acknowledged
# 6       51V  Acknowledged
# 7       53V     Completed
# 8       57H  Acknowledged
# 9       57V  Acknowledged
# 10      58H  Acknowledged
# 11      60H  Acknowledged
# 12      64H  Acknowledged
# 13      74V  Acknowledged
# 14      75H  Acknowledged
# 15      76H  Acknowledged
# 16      76V  Acknowledged
# 17      66H  Acknowledged
# 18      67H  Acknowledged
# 19      69H  Acknowledged
# 20      69V  Acknowledged
# 21      70V  Acknowledged
# 22  9.2.6-A  Acknowledged
# 23  9.2.1-A  Acknowledged
# 24    9.2.2  Acknowledged
# 25    9.2.3  Acknowledged
# 26    9.2.5  Acknowledged
# 27  9.2.6-B  Acknowledged
# 28    9.4.1  Acknowledged
# 29    9.4.2  Acknowledged
# 30   12.4.1  Acknowledged
# 31   12.4.3  Acknowledged
# 32   13.2.1  Acknowledged
# 4H
# 2H
# 31H
# 49H
# 49V
# 51V
# 53V
# 57H
# 57V
# 58H
# 60H
# 64H
# 74V
# 75H
# 76H
# 76V
# 66H
# 67H
# 69H
# 69V
# 70V
# C - Database
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2        2H  Acknowledged
# 3       31H  Acknowledged
# 4       49H  Acknowledged
# 5       49V  Acknowledged
# 6       51V  Acknowledged
# 7       53V     Completed
# 8       57H  Acknowledged
# 9       57V  Acknowledged
# 10      58H  Acknowledged
# 11      60H  Acknowledged
# 12      64H  Acknowledged
# 13      74V  Acknowledged
# 14      75H  Acknowledged
# 15      76H  Acknowledged
# 16      76V  Acknowledged
# 17      66H  Acknowledged
# 18      67H  Acknowledged
# 19      69H  Acknowledged
# 20      69V  Acknowledged
# 21      70V  Acknowledged
# 22  9.2.6-A  Acknowledged
# 23  9.2.1-A  Acknowledged
# 24    9.2.2  Acknowledged
# 25    9.2.3  Acknowledged
# 26    9.2.5  Acknowledged
# 27  9.2.6-B  Acknowledged
# 28    9.4.1  Acknowledged
# 29    9.4.2  Acknowledged
# 30   12.4.1  Acknowledged
# 31   12.4.3  Acknowledged
# 32   13.2.1  Acknowledged
# 4H
# 2H
# 31H
# 49H
# 49V
# 51V
# 53V
# 57H
# 57V
# 58H
# 60H
# 64H
# 74V
# 75H
# 76H
# 76V
# 66H
# 67H
# 69H
# 69V
# 70V
# GDPR-RS-EPS102-Remote Monitoring & Control Solutions (new)-V4.0 RELEASED....xlsx
# A - RMCS
#      Req nr      Response
# 0       NaN           NaN
# 1        3H  Acknowledged
# 2        4H  Acknowledged
# 3       51V  Acknowledged
# 4       52H  Acknowledged
# 5       52V  Acknowledged
# 6       58H  Acknowledged
# 7       60H  Acknowledged
# 8       63H  Acknowledged
# 9       64H  Acknowledged
# 10      76H  Acknowledged
# 11      76V  Acknowledged
# 12       2H  Acknowledged
# 13       8H  Acknowledged
# 14      10V  Acknowledged
# 15      12H  Acknowledged
# 16      12V  Acknowledged
# 17     13aH  Acknowledged
# 18     13aV  Acknowledged
# 19     13bH  Acknowledged
# 20     13bV  Acknowledged
# 21      14H  Acknowledged
# 22      14V  Acknowledged
# 23      23V  Acknowledged
# 24      27V  Acknowledged
# 25      28V  Acknowledged
# 26      38H  Acknowledged
# 27      38V  Acknowledged
# 28      40H  Acknowledged
# 29      40V  Acknowledged
# 30      42H  Acknowledged
# 31      42V  Acknowledged
# 32      44V  Acknowledged
# 33      45V  Acknowledged
# 34      48H  Acknowledged
# 35      48V  Acknowledged
# 36      61H  Acknowledged
# 37      61V  Acknowledged
# 38      66H  Acknowledged
# 39      67H  Acknowledged
# 40      68H  Acknowledged
# 41      70V  Acknowledged
# 42      71V  Acknowledged
# 43      72V  Acknowledged
# 44      73H  Acknowledged
# 45      74V  Acknowledged
# 46      75H  Acknowledged
# 47  9.2.6-A  Acknowledged
# 48  9.2.6-B  Acknowledged
# 49   12.4.3  Acknowledged
# 50   13.2.1  Acknowledged
# 51   18.1.4  Acknowledged
# 52  9.2.1-A  Acknowledged
# 53    9.2.2  Acknowledged
# 54    9.2.3  Acknowledged
# 55    9.2.5  Acknowledged
# 56    9.4.1  Acknowledged
# 57   12.4.1  Acknowledged
# 58   13.2.2  Acknowledged
# 59   14.1.2  Acknowledged
# 10V
# 12H
# 15    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 14H
# 14V
# 23V
# 27V
# 28V
# 38H
# 38V
# 3H
# 40H
# 40V
# 42H
# 42V
# 44V
# 45V
# 48H
# 48V
# 52H
# 52V
# 61H
# 61V
# 63H
# 68H
# 71V
# 72V
# 73H
# 8H
# 4H
# 2H
# 51V
# 58H
# 60H
# 64H
# 74V
# 75H
# 76H
# 76V
# 66H
# 67H
# 70V
# GDPR-RS-EPS089-NB-IoT-V4.0 MAPPED.xlsx
# A - Message Broker
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       52H  Acknowledged
# 3       52V  Acknowledged
# 4       71V  Acknowledged
# 5        2H  Acknowledged
# 6       11H  Acknowledged
# 7       11V  Acknowledged
# 8       12H  Acknowledged
# 9       12V  Acknowledged
# 10     13aH  Acknowledged
# 11     13aV  Acknowledged
# 12     13bH  Acknowledged
# 13     13bV  Acknowledged
# 14      22V  Acknowledged
# 15      23V  Acknowledged
# 16      35H  Acknowledged
# 17      45V  Acknowledged
# 18      51V     Completed
# 19      53V  Acknowledged
# 20      54V  Acknowledged
# 21      57H  Acknowledged
# 22      57V  Acknowledged
# 23      60H  Acknowledged
# 24      61H  Acknowledged
# 25      61V  Acknowledged
# 26      72V  Acknowledged
# 27      73H  Acknowledged
# 28      74V  Acknowledged
# 29      76H  Acknowledged
# 30      76V  Acknowledged
# 31   13.2.1  Acknowledged
# 32   13.2.2  Acknowledged
# 33  9.2.1-A  Acknowledged
# 34    9.2.2  Acknowledged
# 35    9.2.3  Acknowledged
# 36    9.2.5  Acknowledged
# 37  9.2.6-A  Acknowledged
# 38  9.2.6-B  Acknowledged
# 39    9.4.1  Acknowledged
# 40    9.4.2  Acknowledged
# 41   12.4.1  Acknowledged
# 42   12.4.3  Acknowledged
# 43   14.1.2  Acknowledged
# 44   18.1.4  Acknowledged
# 11H
# 11V
# 22V
# 35H
# 53V
# 54V
# 57H
# 57V
# 4H
# 51V
# 52H
# 52V
# 60H
# 76H
# 76V
# 12H
# 8    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 23V
# 2H
# 45V
# 61H
# 61V
# 71V
# 72V
# 73H
# 74V
# B - Miscellaneous
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       52H  Acknowledged
# 3       52V  Acknowledged
# 4       71V  Acknowledged
# 5        2H  Acknowledged
# 6       11H  Acknowledged
# 7       11V  Acknowledged
# 8       12H  Acknowledged
# 9       12V  Acknowledged
# 10     13aH  Acknowledged
# 11     13aV  Acknowledged
# 12     13bH  Acknowledged
# 13     13bV  Acknowledged
# 14      22V  Acknowledged
# 15      23V  Acknowledged
# 16      35H  Acknowledged
# 17      45V  Acknowledged
# 18      51V     Completed
# 19      53V  Acknowledged
# 20      54V  Acknowledged
# 21      57H  Acknowledged
# 22      57V  Acknowledged
# 23      60H  Acknowledged
# 24      61H  Acknowledged
# 25      61V  Acknowledged
# 26      72V  Acknowledged
# 27      73H  Acknowledged
# 28      74V  Acknowledged
# 29      76H  Acknowledged
# 30      76V  Acknowledged
# 31   13.2.1  Acknowledged
# 32   13.2.2  Acknowledged
# 33  9.2.1-A  Acknowledged
# 34    9.2.2  Acknowledged
# 35    9.2.3  Acknowledged
# 36    9.2.5  Acknowledged
# 37  9.2.6-A  Acknowledged
# 38  9.2.6-B  Acknowledged
# 39    9.4.1  Acknowledged
# 40    9.4.2  Acknowledged
# 41   12.4.1  Acknowledged
# 42   12.4.3  Acknowledged
# 43   14.1.2  Acknowledged
# 44   18.1.4  Acknowledged
# 4H
# 52H
# 52V
# 71V
# 11H
# 11V
# 12H
# 8    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 22V
# 23V
# 2H
# 35H
# 45V
# 51V
# 53V
# 54V
# 57H
# 57V
# 60H
# 61H
# 61V
# 72V
# 73H
# 74V
# 76H
# 76V
# GDPR-RS-EPS097-AEP IEP-V4.0 RELEASED -- AS Reviewed 18.04.2018.xlsx
# A - IEP
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       73H  Acknowledged
# 3        5H  Acknowledged
# 4       11H  Acknowledged
# 5       11V     Completed
# 6       12H  Acknowledged
# 7       12V     Completed
# 8      13aH  Acknowledged
# 9      13aV     Completed
# 10     13bH  Acknowledged
# 11     13bV     Completed
# 12      16V  Acknowledged
# 13      27V  Acknowledged
# 14      28V     Completed
# 15      45V  Acknowledged
# 16      51V  Acknowledged
# 17      59V  Acknowledged
# 18      60H  Acknowledged
# 19      66H  Acknowledged
# 20      67H  Acknowledged
# 21      70V  Acknowledged
# 22      71V  Acknowledged
# 23      75H  Acknowledged
# 24      76H  Acknowledged
# 25      76V  Acknowledged
# 26      62H  Acknowledged
# 27      62V  Acknowledged
# 28  9.2.6-A  Acknowledged
# 29  9.2.6-B  Acknowledged
# 30   12.4.3  Acknowledged
# 31   13.2.1  Acknowledged
# 32   18.1.4  Acknowledged
# 33  9.2.1-A  Acknowledged
# 34    9.2.2  Acknowledged
# 35    9.2.3  Acknowledged
# 36    9.2.5  Acknowledged
# 37    9.4.1  Acknowledged
# 38   12.4.1  Acknowledged
# 39   13.2.2  Acknowledged
# 40   14.1.2  Acknowledged
# 16V
# 27V
# 28V
# 59V
# 5H
# 62H
# 62V
# 66H
# 67H
# 70V
# 75H
# 4H
# 71V
# 11H
# 11V
# 12H
# 6    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 45V
# 51V
# 60H
# 73H
# 76H
# 76V
# GDPR-RS-EPS068-Global M2M Platform (GDSP IT)-V4.0 MAPPED.xlsx
# A - Portal
#      Req nr      Response
# 0       NaN           NaN
# 1       11H  Acknowledged
# 2       11V  Acknowledged
# 3       12H  Acknowledged
# 4       12V  Acknowledged
# 5      13aH  Acknowledged
# 6      13aV  Acknowledged
# 7      13bH  Acknowledged
# 8      13bV  Acknowledged
# 9       51V  Acknowledged
# 10      63H  Acknowledged
# 11      73H  Acknowledged
# 12       1H  Acknowledged
# 13       2H  Acknowledged
# 14      15V  Acknowledged
# 15      16V  Acknowledged
# 16      52H  Acknowledged
# 17      52V      Rejected
# 18      53V     Completed
# 19      57H  Acknowledged
# 20      57V  Acknowledged
# 21      58H  Acknowledged
# 22      60H  Acknowledged
# 23      64H  Acknowledged
# 24      66H  Acknowledged
# 25      67H  Acknowledged
# 26      69H  Acknowledged
# 27      69V  Acknowledged
# 28      70V  Acknowledged
# 29      74V  Acknowledged
# 30      75H  Acknowledged
# 31      76H  Acknowledged
# 32      76V  Acknowledged
# 33      28V  Acknowledged
# 34      61H  Acknowledged
# 35      61V  Acknowledged
# 36   13.2.2  Acknowledged
# 37  9.2.1-A  Acknowledged
# 38    9.2.2  Acknowledged
# 39    9.2.3  Acknowledged
# 40    9.2.5  Acknowledged
# 41  9.2.6-A  Acknowledged
# 42  9.2.6-B  Acknowledged
# 43   18.1.4  Acknowledged
# 44    9.4.1  Acknowledged
# 45    9.4.2  Acknowledged
# 46   12.4.1  Acknowledged
# 47   12.4.3  Acknowledged
# 48   13.2.1  Acknowledged
# 49   14.1.2  Acknowledged
# 15V
# 1H
# 2H
# 52H
# 52V
# 53V
# 57H
# 57V
# 58H
# 61H
# 61V
# 63H
# 64H
# 69H
# 69V
# 74V
# 11V
# 12V
# 13aV
# 13bV
# 28V
# 73H
# 11H
# 12H
# 3    Acknowledged
# Name: Response, dtype: object
# 13aH
# 13bH
# 16V
# 51V
# 60H
# 66H
# 67H
# 70V
# 75H
# 76H
# 76V
# B - Business Logic
#      Req nr      Response
# 0       NaN           NaN
# 1       11H  Acknowledged
# 2       11V  Acknowledged
# 3       12H  Acknowledged
# 4       12V  Acknowledged
# 5      13aH  Acknowledged
# 6      13aV  Acknowledged
# 7      13bH  Acknowledged
# 8      13bV  Acknowledged
# 9       51V  Acknowledged
# 10      63H  Acknowledged
# 11      73H  Acknowledged
# 12       1H  Acknowledged
# 13       2H  Acknowledged
# 14      15V  Acknowledged
# 15      16V  Acknowledged
# 16      52H  Acknowledged
# 17      52V      Rejected
# 18      53V     Completed
# 19      57H  Acknowledged
# 20      57V  Acknowledged
# 21      58H  Acknowledged
# 22      60H  Acknowledged
# 23      64H  Acknowledged
# 24      66H  Acknowledged
# 25      67H  Acknowledged
# 26      69H  Acknowledged
# 27      69V  Acknowledged
# 28      70V  Acknowledged
# 29      74V  Acknowledged
# 30      75H  Acknowledged
# 31      76H  Acknowledged
# 32      76V  Acknowledged
# 33      28V  Acknowledged
# 34      61H  Acknowledged
# 35      61V  Acknowledged
# 36   13.2.2  Acknowledged
# 37  9.2.1-A  Acknowledged
# 38    9.2.2  Acknowledged
# 39    9.2.3  Acknowledged
# 40    9.2.5  Acknowledged
# 41  9.2.6-A  Acknowledged
# 42  9.2.6-B  Acknowledged
# 43   18.1.4  Acknowledged
# 44    9.4.1  Acknowledged
# 45    9.4.2  Acknowledged
# 46   12.4.1  Acknowledged
# 47   12.4.3  Acknowledged
# 48   13.2.1  Acknowledged
# 49   14.1.2  Acknowledged
# 11H
# 11V
# 12H
# 3    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 51V
# 63H
# 73H
# 15V
# 16V
# 1H
# 2H
# 52H
# 52V
# 53V
# 57H
# 57V
# 58H
# 60H
# 64H
# 66H
# 67H
# 69H
# 69V
# 70V
# 74V
# 75H
# 76H
# 76V
# 28V
# 61H
# 61V
# C - Data Exposure
#      Req nr      Response
# 0       NaN           NaN
# 1       11H  Acknowledged
# 2       11V  Acknowledged
# 3       12H  Acknowledged
# 4       12V  Acknowledged
# 5      13aH  Acknowledged
# 6      13aV  Acknowledged
# 7      13bH  Acknowledged
# 8      13bV  Acknowledged
# 9       51V  Acknowledged
# 10      63H  Acknowledged
# 11      73H  Acknowledged
# 12       1H  Acknowledged
# 13       2H  Acknowledged
# 14      15V  Acknowledged
# 15      16V  Acknowledged
# 16      52H  Acknowledged
# 17      52V      Rejected
# 18      53V     Completed
# 19      57H  Acknowledged
# 20      57V  Acknowledged
# 21      58H  Acknowledged
# 22      60H  Acknowledged
# 23      64H  Acknowledged
# 24      66H  Acknowledged
# 25      67H  Acknowledged
# 26      69H  Acknowledged
# 27      69V  Acknowledged
# 28      70V  Acknowledged
# 29      74V  Acknowledged
# 30      75H  Acknowledged
# 31      76H  Acknowledged
# 32      76V  Acknowledged
# 33      28V  Acknowledged
# 34      61H  Acknowledged
# 35      61V  Acknowledged
# 36   13.2.2  Acknowledged
# 37  9.2.1-A  Acknowledged
# 38    9.2.2  Acknowledged
# 39    9.2.3  Acknowledged
# 40    9.2.5  Acknowledged
# 41  9.2.6-A  Acknowledged
# 42  9.2.6-B  Acknowledged
# 43   18.1.4  Acknowledged
# 44    9.4.1  Acknowledged
# 45    9.4.2  Acknowledged
# 46   12.4.1  Acknowledged
# 47   12.4.3  Acknowledged
# 48   13.2.1  Acknowledged
# 49   14.1.2  Acknowledged
# 11H
# 11V
# 12H
# 3    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 51V
# 63H
# 73H
# 15V
# 16V
# 1H
# 2H
# 52H
# 52V
# 53V
# 57H
# 57V
# 58H
# 60H
# 64H
# 66H
# 67H
# 69H
# 69V
# 70V
# 74V
# 75H
# 76H
# 76V
# 28V
# 61H
# 61V
# D - NW Integration
#      Req nr      Response
# 0       NaN           NaN
# 1       11H  Acknowledged
# 2       11V  Acknowledged
# 3       12H  Acknowledged
# 4       12V  Acknowledged
# 5      13aH  Acknowledged
# 6      13aV  Acknowledged
# 7      13bH  Acknowledged
# 8      13bV  Acknowledged
# 9       51V  Acknowledged
# 10      63H  Acknowledged
# 11      73H  Acknowledged
# 12       1H  Acknowledged
# 13       2H  Acknowledged
# 14      15V  Acknowledged
# 15      16V  Acknowledged
# 16      52H  Acknowledged
# 17      52V      Rejected
# 18      53V     Completed
# 19      57H  Acknowledged
# 20      57V  Acknowledged
# 21      58H  Acknowledged
# 22      60H  Acknowledged
# 23      64H  Acknowledged
# 24      66H  Acknowledged
# 25      67H  Acknowledged
# 26      69H  Acknowledged
# 27      69V  Acknowledged
# 28      70V  Acknowledged
# 29      74V  Acknowledged
# 30      75H  Acknowledged
# 31      76H  Acknowledged
# 32      76V  Acknowledged
# 33      28V  Acknowledged
# 34      61H  Acknowledged
# 35      61V  Acknowledged
# 36   13.2.2  Acknowledged
# 37  9.2.1-A  Acknowledged
# 38    9.2.2  Acknowledged
# 39    9.2.3  Acknowledged
# 40    9.2.5  Acknowledged
# 41  9.2.6-A  Acknowledged
# 42  9.2.6-B  Acknowledged
# 43   18.1.4  Acknowledged
# 44    9.4.1  Acknowledged
# 45    9.4.2  Acknowledged
# 46   12.4.1  Acknowledged
# 47   12.4.3  Acknowledged
# 48   13.2.1  Acknowledged
# 49   14.1.2  Acknowledged
# 11H
# 11V
# 12H
# 3    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 51V
# 63H
# 73H
# 15V
# 16V
# 1H
# 2H
# 52H
# 52V
# 53V
# 57H
# 57V
# 58H
# 60H
# 64H
# 66H
# 67H
# 69H
# 69V
# 70V
# 74V
# 75H
# 76H
# 76V
# 28V
# 61H
# 61V
# E - Database
#      Req nr      Response
# 0       NaN           NaN
# 1       11H  Acknowledged
# 2       11V  Acknowledged
# 3       12H  Acknowledged
# 4       12V  Acknowledged
# 5      13aH  Acknowledged
# 6      13aV  Acknowledged
# 7      13bH  Acknowledged
# 8      13bV  Acknowledged
# 9       51V  Acknowledged
# 10      63H  Acknowledged
# 11      73H  Acknowledged
# 12       1H  Acknowledged
# 13       2H  Acknowledged
# 14      15V  Acknowledged
# 15      16V  Acknowledged
# 16      52H  Acknowledged
# 17      52V      Rejected
# 18      53V     Completed
# 19      57H  Acknowledged
# 20      57V  Acknowledged
# 21      58H  Acknowledged
# 22      60H  Acknowledged
# 23      64H  Acknowledged
# 24      66H  Acknowledged
# 25      67H  Acknowledged
# 26      69H  Acknowledged
# 27      69V  Acknowledged
# 28      70V  Acknowledged
# 29      74V  Acknowledged
# 30      75H  Acknowledged
# 31      76H  Acknowledged
# 32      76V  Acknowledged
# 33      28V  Acknowledged
# 34      61H  Acknowledged
# 35      61V  Acknowledged
# 36   13.2.2  Acknowledged
# 37  9.2.1-A  Acknowledged
# 38    9.2.2  Acknowledged
# 39    9.2.3  Acknowledged
# 40    9.2.5  Acknowledged
# 41  9.2.6-A  Acknowledged
# 42  9.2.6-B  Acknowledged
# 43   18.1.4  Acknowledged
# 44    9.4.1  Acknowledged
# 45    9.4.2  Acknowledged
# 46   12.4.1  Acknowledged
# 47   12.4.3  Acknowledged
# 48   13.2.1  Acknowledged
# 49   14.1.2  Acknowledged
# 11H
# 11V
# 12H
# 3    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 51V
# 63H
# 73H
# 15V
# 16V
# 1H
# 2H
# 52H
# 52V
# 53V
# 57H
# 57V
# 58H
# 60H
# 64H
# 66H
# 67H
# 69H
# 69V
# 70V
# 74V
# 75H
# 76H
# 76V
# 28V
# 61H
# 61V
# GDPR-RS-EPS090-GDSP - NW-V4.0 MAPPED.xlsx
# A - NGIN
#    Req nr      Response
# 0     NaN           NaN
# 1      4H  Acknowledged
# 2     73H  Acknowledged
# 3      2H  Acknowledged
# 4      5H  Acknowledged
# 5      6V     Completed
# 6      7V  Acknowledged
# 7      9V     Completed
# 8     51V  Acknowledged
# 9     66H  Acknowledged
# 10    67H  Acknowledged
# 11    70V  Acknowledged
# 12    75H  Acknowledged
# 13    76H  Acknowledged
# 14    76V  Acknowledged
# 4H
# 5H
# 6V
# 7V
# 9V
# 51V
# 73H
# 2H
# 66H
# 67H
# 70V
# 75H
# 76H
# 76V
# B - SMSC
#    Req nr      Response
# 0     NaN           NaN
# 1      4H  Acknowledged
# 2     73H  Acknowledged
# 3      2H  Acknowledged
# 4      5H  Acknowledged
# 5      6V     Completed
# 6      7V  Acknowledged
# 7      9V     Completed
# 8     51V  Acknowledged
# 9     66H  Acknowledged
# 10    67H  Acknowledged
# 11    70V  Acknowledged
# 12    75H  Acknowledged
# 13    76H  Acknowledged
# 14    76V  Acknowledged
# 4H
# 73H
# 2H
# 51V
# 5H
# 66H
# 67H
# 6V
# 70V
# 75H
# 76H
# 76V
# 7V
# 9V
# C - GGSN
#    Req nr      Response
# 0     NaN           NaN
# 1      4H  Acknowledged
# 2     73H  Acknowledged
# 3      2H  Acknowledged
# 4      5H  Acknowledged
# 5      6V     Completed
# 6      7V  Acknowledged
# 7      9V     Completed
# 8     51V  Acknowledged
# 9     66H  Acknowledged
# 10    67H  Acknowledged
# 11    70V  Acknowledged
# 12    75H  Acknowledged
# 13    76H  Acknowledged
# 14    76V  Acknowledged
# 4H
# 73H
# 2H
# 51V
# 5H
# 66H
# 67H
# 6V
# 70V
# 75H
# 76H
# 76V
# 7V
# 9V
# D - HLR
#    Req nr      Response
# 0     NaN           NaN
# 1      4H  Acknowledged
# 2     73H  Acknowledged
# 3      2H  Acknowledged
# 4      5H  Acknowledged
# 5      6V     Completed
# 6      7V  Acknowledged
# 7      9V     Completed
# 8     51V  Acknowledged
# 9     66H  Acknowledged
# 10    67H  Acknowledged
# 11    70V  Acknowledged
# 12    75H  Acknowledged
# 13    76H  Acknowledged
# 14    76V  Acknowledged
# 4H
# 73H
# 2H
# 51V
# 5H
# 66H
# 67H
# 6V
# 70V
# 75H
# 76H
# 76V
# 7V
# 9V
# GDPR-RS-EPS103-Smart Cities (SmartBin Application)-V4.0 RELEASED -- AS R....xlsx
# A - Portal
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       51V  Acknowledged
# 3       57H  Acknowledged
# 4       57V  Acknowledged
# 5       58H  Acknowledged
# 6       66H  Acknowledged
# 7       67H  Acknowledged
# 8       73H  Acknowledged
# 9        2H  Acknowledged
# 10      11H  Acknowledged
# 11      11V  Acknowledged
# 12      12H  Acknowledged
# 13      12V  Acknowledged
# 14      27V  Acknowledged
# 15      44V  Acknowledged
# 16      45V  Acknowledged
# 17      48H  Acknowledged
# 18      48V  Acknowledged
# 19      50H  Acknowledged
# 20      60H  Acknowledged
# 21      69H  Acknowledged
# 22      69V  Acknowledged
# 23      70V  Acknowledged
# 24      75H  Acknowledged
# 25      76H  Acknowledged
# 26      76V  Acknowledged
# 27       6V     Completed
# 28       7V     Completed
# 29     13aH  Acknowledged
# 30     13aV  Acknowledged
# 31     13bH  Acknowledged
# 32     13bV  Acknowledged
# 33      74V  Acknowledged
# 34  9.2.6-A  Acknowledged
# 35  9.2.6-B  Acknowledged
# 36   12.4.3  Acknowledged
# 37   13.2.1  Acknowledged
# 38   18.1.4  Acknowledged
# 39  9.2.1-A  Acknowledged
# 40    9.2.2  Acknowledged
# 41    9.2.3  Acknowledged
# 42    9.2.5  Acknowledged
# 43    9.4.1  Acknowledged
# 44   12.4.1  Acknowledged
# 45   13.2.2  Acknowledged
# 46   14.1.2  Acknowledged
# 11H
# 11V
# 12H
# 12    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 27V
# 44V
# 45V
# 48H
# 48V
# 50H
# 57H
# 57V
# 58H
# 60H
# 69H
# 69V
# 74V
# 4H
# 73H
# 2H
# 51V
# 66H
# 67H
# 6V
# 70V
# 75H
# 76H
# 76V
# 7V
# B - Business Logic
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       51V  Acknowledged
# 3       57H  Acknowledged
# 4       57V  Acknowledged
# 5       58H  Acknowledged
# 6       66H  Acknowledged
# 7       67H  Acknowledged
# 8       73H  Acknowledged
# 9        2H  Acknowledged
# 10      11H  Acknowledged
# 11      11V  Acknowledged
# 12      12H  Acknowledged
# 13      12V  Acknowledged
# 14      27V  Acknowledged
# 15      44V  Acknowledged
# 16      45V  Acknowledged
# 17      48H  Acknowledged
# 18      48V  Acknowledged
# 19      50H  Acknowledged
# 20      60H  Acknowledged
# 21      69H  Acknowledged
# 22      69V  Acknowledged
# 23      70V  Acknowledged
# 24      75H  Acknowledged
# 25      76H  Acknowledged
# 26      76V  Acknowledged
# 27       6V     Completed
# 28       7V     Completed
# 29     13aH  Acknowledged
# 30     13aV  Acknowledged
# 31     13bH  Acknowledged
# 32     13bV  Acknowledged
# 33      74V  Acknowledged
# 34  9.2.6-A  Acknowledged
# 35  9.2.6-B  Acknowledged
# 36   12.4.3  Acknowledged
# 37   13.2.1  Acknowledged
# 38   18.1.4  Acknowledged
# 39  9.2.1-A  Acknowledged
# 40    9.2.2  Acknowledged
# 41    9.2.3  Acknowledged
# 42    9.2.5  Acknowledged
# 43    9.4.1  Acknowledged
# 44   12.4.1  Acknowledged
# 45   13.2.2  Acknowledged
# 46   14.1.2  Acknowledged
# 6V
# 7V
# 4H
# 51V
# 57H
# 57V
# 58H
# 66H
# 67H
# 73H
# 11H
# 11V
# 12H
# 12    Acknowledged
# Name: Response, dtype: object
# 12V
# 27V
# 2H
# 44V
# 45V
# 48H
# 48V
# 50H
# 60H
# 69H
# 69V
# 70V
# 75H
# 76H
# 76V
# 13aH
# 13aV
# 13bH
# 13bV
# 74V
# C - DM Application
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       51V  Acknowledged
# 3       57H  Acknowledged
# 4       57V  Acknowledged
# 5       58H  Acknowledged
# 6       66H  Acknowledged
# 7       67H  Acknowledged
# 8       73H  Acknowledged
# 9        2H  Acknowledged
# 10      11H  Acknowledged
# 11      11V  Acknowledged
# 12      12H  Acknowledged
# 13      12V  Acknowledged
# 14      27V  Acknowledged
# 15      44V  Acknowledged
# 16      45V  Acknowledged
# 17      48H  Acknowledged
# 18      48V  Acknowledged
# 19      50H  Acknowledged
# 20      60H  Acknowledged
# 21      69H  Acknowledged
# 22      69V  Acknowledged
# 23      70V  Acknowledged
# 24      75H  Acknowledged
# 25      76H  Acknowledged
# 26      76V  Acknowledged
# 27       6V     Completed
# 28       7V     Completed
# 29     13aH  Acknowledged
# 30     13aV  Acknowledged
# 31     13bH  Acknowledged
# 32     13bV  Acknowledged
# 33      74V  Acknowledged
# 34  9.2.6-A  Acknowledged
# 35  9.2.6-B  Acknowledged
# 36   12.4.3  Acknowledged
# 37   13.2.1  Acknowledged
# 38   18.1.4  Acknowledged
# 39  9.2.1-A  Acknowledged
# 40    9.2.2  Acknowledged
# 41    9.2.3  Acknowledged
# 42    9.2.5  Acknowledged
# 43    9.4.1  Acknowledged
# 44   12.4.1  Acknowledged
# 45   13.2.2  Acknowledged
# 46   14.1.2  Acknowledged
# 4H
# 51V
# 57H
# 57V
# 58H
# 66H
# 67H
# 73H
# 11H
# 11V
# 12H
# 12    Acknowledged
# Name: Response, dtype: object
# 12V
# 27V
# 2H
# 44V
# 45V
# 48H
# 48V
# 50H
# 60H
# 69H
# 69V
# 70V
# 75H
# 76H
# 76V
# 13aH
# 13aV
# 13bH
# 13bV
# 6V
# 74V
# 7V
# D - Database
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       51V  Acknowledged
# 3       57H  Acknowledged
# 4       57V  Acknowledged
# 5       58H  Acknowledged
# 6       66H  Acknowledged
# 7       67H  Acknowledged
# 8       73H  Acknowledged
# 9        2H  Acknowledged
# 10      11H  Acknowledged
# 11      11V  Acknowledged
# 12      12H  Acknowledged
# 13      12V  Acknowledged
# 14      27V  Acknowledged
# 15      44V  Acknowledged
# 16      45V  Acknowledged
# 17      48H  Acknowledged
# 18      48V  Acknowledged
# 19      50H  Acknowledged
# 20      60H  Acknowledged
# 21      69H  Acknowledged
# 22      69V  Acknowledged
# 23      70V  Acknowledged
# 24      75H  Acknowledged
# 25      76H  Acknowledged
# 26      76V  Acknowledged
# 27       6V     Completed
# 28       7V     Completed
# 29     13aH  Acknowledged
# 30     13aV  Acknowledged
# 31     13bH  Acknowledged
# 32     13bV  Acknowledged
# 33      74V  Acknowledged
# 34  9.2.6-A  Acknowledged
# 35  9.2.6-B  Acknowledged
# 36   12.4.3  Acknowledged
# 37   13.2.1  Acknowledged
# 38   18.1.4  Acknowledged
# 39  9.2.1-A  Acknowledged
# 40    9.2.2  Acknowledged
# 41    9.2.3  Acknowledged
# 42    9.2.5  Acknowledged
# 43    9.4.1  Acknowledged
# 44   12.4.1  Acknowledged
# 45   13.2.2  Acknowledged
# 46   14.1.2  Acknowledged
# 4H
# 51V
# 57H
# 57V
# 58H
# 66H
# 67H
# 73H
# 11H
# 11V
# 12H
# 12    Acknowledged
# Name: Response, dtype: object
# 12V
# 27V
# 2H
# 44V
# 45V
# 48H
# 48V
# 50H
# 60H
# 69H
# 69V
# 70V
# 75H
# 76H
# 76V
# 13aH
# 13aV
# 13bH
# 13bV
# 6V
# 74V
# 7V
# GDPR-RS-EPS067-Internet In The Car (IITC)-V4.0 MAPPED.xlsx
# A - B2B-B2C Portal
#      Req nr      Response
# 0       NaN           NaN
# 1       51V     Completed
# 2       55V     Completed
# 3       61H  Acknowledged
# 4       61V  Acknowledged
# 5       71V  Acknowledged
# 6        2H  Acknowledged
# 7        3H  Acknowledged
# 8       11H  Acknowledged
# 9       11V  Acknowledged
# 10      12H  Acknowledged
# 11      12V  Acknowledged
# 12     13aH  Acknowledged
# 13     13aV  Acknowledged
# 14     13bH  Acknowledged
# 15     13bV  Acknowledged
# 16      15V  Acknowledged
# 17      16V  Acknowledged
# 18      28V  Acknowledged
# 19      31H  Acknowledged
# 20      37H  Acknowledged
# 21      37V  Acknowledged
# 22      44V  Acknowledged
# 23      45V  Acknowledged
# 24      46H  Acknowledged
# 25      46V  Acknowledged
# 26      49H  Acknowledged
# 27      49V     Completed
# 28      52H  Acknowledged
# 29      52V  Acknowledged
# ..      ...           ...
# 33      67H  Acknowledged
# 34      70V  Acknowledged
# 35      73H  Acknowledged
# 36      74V  Acknowledged
# 37      75H  Acknowledged
# 38      76H  Acknowledged
# 39      76V  Acknowledged
# 40      38H  Acknowledged
# 41      38V  Acknowledged
# 42      40H  Acknowledged
# 43      40V  Acknowledged
# 44      42H  Acknowledged
# 45      42V  Acknowledged
# 46      47H  Acknowledged
# 47      47V  Acknowledged
# 48      59V  Acknowledged
# 49   13.2.2  Acknowledged
# 50  9.2.1-A  Acknowledged
# 51    9.2.2  Acknowledged
# 52    9.2.3  Acknowledged
# 53    9.2.5  Acknowledged
# 54  9.2.6-A  Acknowledged
# 55  9.2.6-B  Acknowledged
# 56   18.1.4  Acknowledged
# 57    9.4.1  Acknowledged
# 58    9.4.2  Acknowledged
# 59   12.4.1  Acknowledged
# 60   12.4.3  Acknowledged
# 61   13.2.1  Acknowledged
# 62   14.1.2  Acknowledged
#
# [63 rows x 2 columns]
# 15V
# 16V
# 28V
# 31H
# 37H
# 37V
# 38H
# 38V
# 3H
# 40H
# 40V
# 42H
# 42V
# 46H
# 46V
# 47H
# 47V
# 49H
# 49V
# 52H
# 52V
# 55V
# 59V
# 61H
# 61V
# 71V
# 51V
# 58H
# 66H
# 67H
# 73H
# 11H
# 11V
# 12H
# 10    Acknowledged
# Name: Response, dtype: object
# 12V
# 2H
# 44V
# 45V
# 60H
# 70V
# 75H
# 76H
# 76V
# 13aH
# 13aV
# 13bH
# 13bV
# 74V
# B - Business Logic
#      Req nr      Response
# 0       NaN           NaN
# 1       51V     Completed
# 2       55V     Completed
# 3       61H  Acknowledged
# 4       61V  Acknowledged
# 5       71V  Acknowledged
# 6        2H  Acknowledged
# 7        3H  Acknowledged
# 8       11H  Acknowledged
# 9       11V  Acknowledged
# 10      12H  Acknowledged
# 11      12V  Acknowledged
# 12     13aH  Acknowledged
# 13     13aV  Acknowledged
# 14     13bH  Acknowledged
# 15     13bV  Acknowledged
# 16      15V  Acknowledged
# 17      16V  Acknowledged
# 18      28V  Acknowledged
# 19      31H  Acknowledged
# 20      37H  Acknowledged
# 21      37V  Acknowledged
# 22      44V  Acknowledged
# 23      45V  Acknowledged
# 24      46H  Acknowledged
# 25      46V  Acknowledged
# 26      49H  Acknowledged
# 27      49V     Completed
# 28      52H  Acknowledged
# 29      52V  Acknowledged
# ..      ...           ...
# 33      67H  Acknowledged
# 34      70V  Acknowledged
# 35      73H  Acknowledged
# 36      74V  Acknowledged
# 37      75H  Acknowledged
# 38      76H  Acknowledged
# 39      76V  Acknowledged
# 40      38H  Acknowledged
# 41      38V  Acknowledged
# 42      40H  Acknowledged
# 43      40V  Acknowledged
# 44      42H  Acknowledged
# 45      42V  Acknowledged
# 46      47H  Acknowledged
# 47      47V  Acknowledged
# 48      59V  Acknowledged
# 49   13.2.2  Acknowledged
# 50  9.2.1-A  Acknowledged
# 51    9.2.2  Acknowledged
# 52    9.2.3  Acknowledged
# 53    9.2.5  Acknowledged
# 54  9.2.6-A  Acknowledged
# 55  9.2.6-B  Acknowledged
# 56   18.1.4  Acknowledged
# 57    9.4.1  Acknowledged
# 58    9.4.2  Acknowledged
# 59   12.4.1  Acknowledged
# 60   12.4.3  Acknowledged
# 61   13.2.1  Acknowledged
# 62   14.1.2  Acknowledged
#
# [63 rows x 2 columns]
# 51V
# 55V
# 61H
# 61V
# 71V
# 11H
# 11V
# 12H
# 10    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 15V
# 16V
# 28V
# 2H
# 31H
# 37H
# 37V
# 3H
# 44V
# 45V
# 46H
# 46V
# 49H
# 49V
# 52H
# 52V
# 58H
# 60H
# 66H
# 67H
# 70V
# 73H
# 74V
# 75H
# 76H
# 76V
# 38H
# 38V
# 40H
# 40V
# 42H
# 42V
# 47H
# 47V
# 59V
# C - Offline Reporting Server
#      Req nr      Response
# 0       NaN           NaN
# 1       51V     Completed
# 2       55V     Completed
# 3       61H  Acknowledged
# 4       61V  Acknowledged
# 5       71V  Acknowledged
# 6        2H  Acknowledged
# 7        3H  Acknowledged
# 8       11H  Acknowledged
# 9       11V  Acknowledged
# 10      12H  Acknowledged
# 11      12V  Acknowledged
# 12     13aH  Acknowledged
# 13     13aV  Acknowledged
# 14     13bH  Acknowledged
# 15     13bV  Acknowledged
# 16      15V  Acknowledged
# 17      16V  Acknowledged
# 18      28V  Acknowledged
# 19      31H  Acknowledged
# 20      37H  Acknowledged
# 21      37V  Acknowledged
# 22      44V  Acknowledged
# 23      45V  Acknowledged
# 24      46H  Acknowledged
# 25      46V  Acknowledged
# 26      49H  Acknowledged
# 27      49V     Completed
# 28      52H  Acknowledged
# 29      52V  Acknowledged
# ..      ...           ...
# 33      67H  Acknowledged
# 34      70V  Acknowledged
# 35      73H  Acknowledged
# 36      74V  Acknowledged
# 37      75H  Acknowledged
# 38      76H  Acknowledged
# 39      76V  Acknowledged
# 40      38H  Acknowledged
# 41      38V  Acknowledged
# 42      40H  Acknowledged
# 43      40V  Acknowledged
# 44      42H  Acknowledged
# 45      42V  Acknowledged
# 46      47H  Acknowledged
# 47      47V  Acknowledged
# 48      59V  Acknowledged
# 49   13.2.2  Acknowledged
# 50  9.2.1-A  Acknowledged
# 51    9.2.2  Acknowledged
# 52    9.2.3  Acknowledged
# 53    9.2.5  Acknowledged
# 54  9.2.6-A  Acknowledged
# 55  9.2.6-B  Acknowledged
# 56   18.1.4  Acknowledged
# 57    9.4.1  Acknowledged
# 58    9.4.2  Acknowledged
# 59   12.4.1  Acknowledged
# 60   12.4.3  Acknowledged
# 61   13.2.1  Acknowledged
# 62   14.1.2  Acknowledged
#
# [63 rows x 2 columns]
# 51V
# 55V
# 61H
# 61V
# 71V
# 11H
# 11V
# 12H
# 10    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 15V
# 16V
# 28V
# 2H
# 31H
# 37H
# 37V
# 3H
# 44V
# 45V
# 46H
# 46V
# 49H
# 49V
# 52H
# 52V
# 58H
# 60H
# 66H
# 67H
# 70V
# 73H
# 74V
# 75H
# 76H
# 76V
# 38H
# 38V
# 40H
# 40V
# 42H
# 42V
# 47H
# 47V
# 59V
# D - Real Time Charging
#      Req nr      Response
# 0       NaN           NaN
# 1       51V     Completed
# 2       55V     Completed
# 3       61H  Acknowledged
# 4       61V  Acknowledged
# 5       71V  Acknowledged
# 6        2H  Acknowledged
# 7        3H  Acknowledged
# 8       11H  Acknowledged
# 9       11V  Acknowledged
# 10      12H  Acknowledged
# 11      12V  Acknowledged
# 12     13aH  Acknowledged
# 13     13aV  Acknowledged
# 14     13bH  Acknowledged
# 15     13bV  Acknowledged
# 16      15V  Acknowledged
# 17      16V  Acknowledged
# 18      28V  Acknowledged
# 19      31H  Acknowledged
# 20      37H  Acknowledged
# 21      37V  Acknowledged
# 22      44V  Acknowledged
# 23      45V  Acknowledged
# 24      46H  Acknowledged
# 25      46V  Acknowledged
# 26      49H  Acknowledged
# 27      49V     Completed
# 28      52H  Acknowledged
# 29      52V  Acknowledged
# ..      ...           ...
# 33      67H  Acknowledged
# 34      70V  Acknowledged
# 35      73H  Acknowledged
# 36      74V  Acknowledged
# 37      75H  Acknowledged
# 38      76H  Acknowledged
# 39      76V  Acknowledged
# 40      38H  Acknowledged
# 41      38V  Acknowledged
# 42      40H  Acknowledged
# 43      40V  Acknowledged
# 44      42H  Acknowledged
# 45      42V  Acknowledged
# 46      47H  Acknowledged
# 47      47V  Acknowledged
# 48      59V  Acknowledged
# 49   13.2.2  Acknowledged
# 50  9.2.1-A  Acknowledged
# 51    9.2.2  Acknowledged
# 52    9.2.3  Acknowledged
# 53    9.2.5  Acknowledged
# 54  9.2.6-A  Acknowledged
# 55  9.2.6-B  Acknowledged
# 56   18.1.4  Acknowledged
# 57    9.4.1  Acknowledged
# 58    9.4.2  Acknowledged
# 59   12.4.1  Acknowledged
# 60   12.4.3  Acknowledged
# 61   13.2.1  Acknowledged
# 62   14.1.2  Acknowledged
#
# [63 rows x 2 columns]
# 51V
# 55V
# 61H
# 61V
# 71V
# 11H
# 11V
# 12H
# 10    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 15V
# 16V
# 28V
# 2H
# 31H
# 37H
# 37V
# 3H
# 44V
# 45V
# 46H
# 46V
# 49H
# 49V
# 52H
# 52V
# 58H
# 60H
# 66H
# 67H
# 70V
# 73H
# 74V
# 75H
# 76H
# 76V
# 38H
# 38V
# 40H
# 40V
# 42H
# 42V
# 47H
# 47V
# 59V
# E - Database
#      Req nr  Response
# 0       NaN       NaN
# 1       51V       NaN
# 2       55V       NaN
# 3       61H       NaN
# 4       61V       NaN
# 5       71V       NaN
# 6        2H       NaN
# 7        3H       NaN
# 8       11H       NaN
# 9       11V       NaN
# 10      12H       NaN
# 11      12V       NaN
# 12     13aH       NaN
# 13     13aV       NaN
# 14     13bH       NaN
# 15     13bV       NaN
# 16      15V       NaN
# 17      16V       NaN
# 18      28V       NaN
# 19      31H       NaN
# 20      37H       NaN
# 21      37V       NaN
# 22      44V       NaN
# 23      45V       NaN
# 24      46H       NaN
# 25      46V       NaN
# 26      49H       NaN
# 27      49V       NaN
# 28      52H       NaN
# 29      52V       NaN
# ..      ...       ...
# 33      67H       NaN
# 34      70V       NaN
# 35      73H       NaN
# 36      74V       NaN
# 37      75H       NaN
# 38      76H       NaN
# 39      76V       NaN
# 40      38H       NaN
# 41      38V       NaN
# 42      40H       NaN
# 43      40V       NaN
# 44      42H       NaN
# 45      42V       NaN
# 46      47H       NaN
# 47      47V       NaN
# 48      59V       NaN
# 49   13.2.2       NaN
# 50  9.2.1-A       NaN
# 51    9.2.2       NaN
# 52    9.2.3       NaN
# 53    9.2.5       NaN
# 54  9.2.6-A       NaN
# 55  9.2.6-B       NaN
# 56   18.1.4       NaN
# 57    9.4.1       NaN
# 58    9.4.2       NaN
# 59   12.4.1       NaN
# 60   12.4.3       NaN
# 61   13.2.1       NaN
# 62   14.1.2       NaN
#
# [63 rows x 2 columns]
# 51V
# 55V
# 61H
# 61V
# 71V
# 11H
# 11V
# 12H
# 10   NaN
# Name: Response, dtype: float64
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 15V
# 16V
# 28V
# 2H
# 31H
# 37H
# 37V
# 3H
# 44V
# 45V
# 46H
# 46V
# 49H
# 49V
# 52H
# 52V
# 58H
# 60H
# 66H
# 67H
# 70V
# 73H
# 74V
# 75H
# 76H
# 76V
# 38H
# 38V
# 40H
# 40V
# 42H
# 42V
# 47H
# 47V
# 59V
# GDPR-RS-EPS091-IoT Enterprise Billing-V4.0 MAPPED.xlsx
# A - GUI
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       57H  Acknowledged
# 3       57V  Acknowledged
# 4       60H  Acknowledged
# 5       63H  Acknowledged
# 6       69H  Acknowledged
# 7       69V  Acknowledged
# 8       70V  Acknowledged
# 9       73H  Acknowledged
# 10       2H  Acknowledged
# 11       6V  Acknowledged
# 12       7V  Acknowledged
# 13      11H  Acknowledged
# 14      11V  Acknowledged
# 15      12H  Acknowledged
# 16      12V  Acknowledged
# 17     13aH  Acknowledged
# 18     13aV  Acknowledged
# 19     13bH  Acknowledged
# 20     13bV  Acknowledged
# 21      15V  Acknowledged
# 22      16V  Acknowledged
# 23      18H  Acknowledged
# 24      18V  Acknowledged
# 25      19V  Acknowledged
# 26      26V  Acknowledged
# 27      44V  Acknowledged
# 28      45V  Acknowledged
# 29      48H  Acknowledged
# 30      48V  Acknowledged
# 31      49H  Acknowledged
# 32      49V  Acknowledged
# 33      51V  Acknowledged
# 34      61H  Acknowledged
# 35      61V  Acknowledged
# 36      62H  Acknowledged
# 37      62V  Acknowledged
# 38      66H  Acknowledged
# 39      67H  Acknowledged
# 40      74V  Acknowledged
# 41      75H  Acknowledged
# 42      76H  Acknowledged
# 43      76V  Acknowledged
# 44      25V  Acknowledged
# 45      32H  Acknowledged
# 46      32V  Acknowledged
# 47    9.2.3  Acknowledged
# 48    9.2.5  Acknowledged
# 49  9.2.6-A  Acknowledged
# 50  9.2.6-B  Acknowledged
# 51   12.4.1  Acknowledged
# 52   12.4.3  Acknowledged
# 53   13.2.1  Acknowledged
# 54   13.2.2  Acknowledged
# 55   18.1.4  Acknowledged
# 56  9.2.1-A  Acknowledged
# 57    9.2.2  Acknowledged
# 58    9.4.1  Acknowledged
# 59    9.4.2  Acknowledged
# 18H
# 18V
# 19V
# 25V
# 26V
# 32H
# 32V
# 48H
# 48V
# 4H
# 57H
# 57V
# 62H
# 62V
# 63H
# 69H
# 69V
# 6V
# 7V
# 51V
# 61H
# 61V
# 11H
# 11V
# 12H
# 15    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 15V
# 16V
# 2H
# 44V
# 45V
# 49H
# 49V
# 60H
# 66H
# 67H
# 70V
# 73H
# 74V
# 75H
# 76H
# 76V
# B - APRM
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       57H  Acknowledged
# 3       57V  Acknowledged
# 4       60H  Acknowledged
# 5       63H  Acknowledged
# 6       69H  Acknowledged
# 7       69V  Acknowledged
# 8       70V  Acknowledged
# 9       73H  Acknowledged
# 10       2H  Acknowledged
# 11       6V  Acknowledged
# 12       7V  Acknowledged
# 13      11H  Acknowledged
# 14      11V  Acknowledged
# 15      12H  Acknowledged
# 16      12V  Acknowledged
# 17     13aH  Acknowledged
# 18     13aV  Acknowledged
# 19     13bH  Acknowledged
# 20     13bV  Acknowledged
# 21      15V  Acknowledged
# 22      16V  Acknowledged
# 23      18H  Acknowledged
# 24      18V  Acknowledged
# 25      19V  Acknowledged
# 26      26V  Acknowledged
# 27      44V  Acknowledged
# 28      45V  Acknowledged
# 29      48H  Acknowledged
# 30      48V  Acknowledged
# 31      49H  Acknowledged
# 32      49V  Acknowledged
# 33      51V  Acknowledged
# 34      61H  Acknowledged
# 35      61V  Acknowledged
# 36      62H  Acknowledged
# 37      62V  Acknowledged
# 38      66H  Acknowledged
# 39      67H  Acknowledged
# 40      74V  Acknowledged
# 41      75H  Acknowledged
# 42      76H  Acknowledged
# 43      76V  Acknowledged
# 44      25V  Acknowledged
# 45      32H  Acknowledged
# 46      32V  Acknowledged
# 47    9.2.3  Acknowledged
# 48    9.2.5  Acknowledged
# 49  9.2.6-A  Acknowledged
# 50  9.2.6-B  Acknowledged
# 51   12.4.1  Acknowledged
# 52   12.4.3  Acknowledged
# 53   13.2.1  Acknowledged
# 54   13.2.2  Acknowledged
# 55   18.1.4  Acknowledged
# 56  9.2.1-A  Acknowledged
# 57    9.2.2  Acknowledged
# 58    9.4.1  Acknowledged
# 59    9.4.2  Acknowledged
# 4H
# 57H
# 57V
# 60H
# 63H
# 69H
# 69V
# 70V
# 73H
# 11H
# 11V
# 12H
# 15    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 15V
# 16V
# 18H
# 18V
# 19V
# 26V
# 2H
# 44V
# 45V
# 48H
# 48V
# 49H
# 49V
# 51V
# 61H
# 61V
# 62H
# 62V
# 66H
# 67H
# 6V
# 74V
# 75H
# 76H
# 76V
# 7V
# 25V
# 32H
# 32V
# C - MZ
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       57H  Acknowledged
# 3       57V  Acknowledged
# 4       60H  Acknowledged
# 5       63H  Acknowledged
# 6       69H  Acknowledged
# 7       69V  Acknowledged
# 8       70V  Acknowledged
# 9       73H  Acknowledged
# 10       2H  Acknowledged
# 11       6V  Acknowledged
# 12       7V  Acknowledged
# 13      11H  Acknowledged
# 14      11V  Acknowledged
# 15      12H  Acknowledged
# 16      12V  Acknowledged
# 17     13aH  Acknowledged
# 18     13aV  Acknowledged
# 19     13bH  Acknowledged
# 20     13bV  Acknowledged
# 21      15V  Acknowledged
# 22      16V  Acknowledged
# 23      18H  Acknowledged
# 24      18V  Acknowledged
# 25      19V  Acknowledged
# 26      26V  Acknowledged
# 27      44V  Acknowledged
# 28      45V  Acknowledged
# 29      48H  Acknowledged
# 30      48V  Acknowledged
# 31      49H  Acknowledged
# 32      49V  Acknowledged
# 33      51V  Acknowledged
# 34      61H  Acknowledged
# 35      61V  Acknowledged
# 36      62H  Acknowledged
# 37      62V  Acknowledged
# 38      66H  Acknowledged
# 39      67H  Acknowledged
# 40      74V  Acknowledged
# 41      75H  Acknowledged
# 42      76H  Acknowledged
# 43      76V  Acknowledged
# 44      25V  Acknowledged
# 45      32H  Acknowledged
# 46      32V  Acknowledged
# 47    9.2.3  Acknowledged
# 48    9.2.5  Acknowledged
# 49  9.2.6-A  Acknowledged
# 50  9.2.6-B  Acknowledged
# 51   12.4.1  Acknowledged
# 52   12.4.3  Acknowledged
# 53   13.2.1  Acknowledged
# 54   13.2.2  Acknowledged
# 55   18.1.4  Acknowledged
# 56  9.2.1-A  Acknowledged
# 57    9.2.2  Acknowledged
# 58    9.4.1  Acknowledged
# 59    9.4.2  Acknowledged
# 4H
# 57H
# 57V
# 60H
# 63H
# 69H
# 69V
# 70V
# 73H
# 11H
# 11V
# 12H
# 15    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 15V
# 16V
# 18H
# 18V
# 19V
# 26V
# 2H
# 44V
# 45V
# 48H
# 48V
# 49H
# 49V
# 51V
# 61H
# 61V
# 62H
# 62V
# 66H
# 67H
# 6V
# 74V
# 75H
# 76H
# 76V
# 7V
# 25V
# 32H
# 32V
# D - Database
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       57H  Acknowledged
# 3       57V  Acknowledged
# 4       60H  Acknowledged
# 5       63H  Acknowledged
# 6       69H  Acknowledged
# 7       69V  Acknowledged
# 8       70V  Acknowledged
# 9       73H  Acknowledged
# 10       2H  Acknowledged
# 11       6V  Acknowledged
# 12       7V  Acknowledged
# 13      11H  Acknowledged
# 14      11V  Acknowledged
# 15      12H  Acknowledged
# 16      12V  Acknowledged
# 17     13aH  Acknowledged
# 18     13aV  Acknowledged
# 19     13bH  Acknowledged
# 20     13bV  Acknowledged
# 21      15V  Acknowledged
# 22      16V  Acknowledged
# 23      18H  Acknowledged
# 24      18V  Acknowledged
# 25      19V  Acknowledged
# 26      26V  Acknowledged
# 27      44V  Acknowledged
# 28      45V  Acknowledged
# 29      48H  Acknowledged
# 30      48V  Acknowledged
# 31      49H  Acknowledged
# 32      49V  Acknowledged
# 33      51V  Acknowledged
# 34      61H  Acknowledged
# 35      61V  Acknowledged
# 36      62H  Acknowledged
# 37      62V  Acknowledged
# 38      66H  Acknowledged
# 39      67H  Acknowledged
# 40      74V  Acknowledged
# 41      75H  Acknowledged
# 42      76H  Acknowledged
# 43      76V  Acknowledged
# 44      25V  Acknowledged
# 45      32H  Acknowledged
# 46      32V  Acknowledged
# 47    9.2.3  Acknowledged
# 48    9.2.5  Acknowledged
# 49  9.2.6-A  Acknowledged
# 50  9.2.6-B  Acknowledged
# 51   12.4.1  Acknowledged
# 52   12.4.3  Acknowledged
# 53   13.2.1  Acknowledged
# 54   13.2.2  Acknowledged
# 55   18.1.4  Acknowledged
# 56  9.2.1-A  Acknowledged
# 57    9.2.2  Acknowledged
# 58    9.4.1  Acknowledged
# 59    9.4.2  Acknowledged
# 4H
# 57H
# 57V
# 60H
# 63H
# 69H
# 69V
# 70V
# 73H
# 11H
# 11V
# 12H
# 15    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 15V
# 16V
# 18H
# 18V
# 19V
# 26V
# 2H
# 44V
# 45V
# 48H
# 48V
# 49H
# 49V
# 51V
# 61H
# 61V
# 62H
# 62V
# 66H
# 67H
# 6V
# 74V
# 75H
# 76H
# 76V
# 7V
# 25V
# 32H
# 32V
# GDPR-RS-EPS110-IoT Device Management-V4.0 RELEASED -- AS Reviewe....xlsx
# A - Portal
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       19V  Acknowledged
# 3       58H  Acknowledged
# 4       61H  Acknowledged
# 5       61V  Acknowledged
# 6       69H  Acknowledged
# 7       69V  Acknowledged
# 8       70V  Acknowledged
# 9        2H  Acknowledged
# 10      11H  Acknowledged
# 11      11V  Acknowledged
# 12      16V  Acknowledged
# 13      44V  Acknowledged
# 14      45V  Acknowledged
# 15      48H  Acknowledged
# 16      48V  Acknowledged
# 17      49H  Acknowledged
# 18      49V      Rejected
# 19      51V  Acknowledged
# 20      60H  Acknowledged
# 21      63H  Acknowledged
# 22      66H  Acknowledged
# 23      67H  Acknowledged
# 24      68H  Acknowledged
# 25      71V  Acknowledged
# 26      75H  Acknowledged
# 27      76H  Acknowledged
# 28      76V  Acknowledged
# 29      12H  Acknowledged
# 30      12V  Acknowledged
# 31     13aH  Acknowledged
# 32     13aV  Acknowledged
# 33     13bH  Acknowledged
# 34     13bV  Acknowledged
# 35   13.2.1  Acknowledged
# 36   13.2.2  Acknowledged
# 37  9.2.1-A  Acknowledged
# 38    9.2.2  Acknowledged
# 39    9.2.3  Acknowledged
# 40    9.2.5  Acknowledged
# 41  9.2.6-A  Acknowledged
# 42  9.2.6-B  Acknowledged
# 43    9.4.1  Acknowledged
# 44    9.4.2  Acknowledged
# 45   12.4.1  Acknowledged
# 46   12.4.3  Acknowledged
# 47   14.1.2  Acknowledged
# 48   18.1.4  Acknowledged
# 58H
# 68H
# 71V
# 4H
# 60H
# 63H
# 69H
# 69V
# 70V
# 11H
# 11V
# 12H
# 29    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# 16V
# 19V
# 2H
# 44V
# 45V
# 48H
# 48V
# 49H
# 49V
# 51V
# 61H
# 61V
# 66H
# 67H
# 75H
# 76H
# 76V
# B - Business Logic
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       19V  Acknowledged
# 3       58H  Acknowledged
# 4       61H  Acknowledged
# 5       61V  Acknowledged
# 6       69H  Acknowledged
# 7       69V  Acknowledged
# 8       70V  Acknowledged
# 9        2H  Acknowledged
# 10      11H  Acknowledged
# 11      11V  Acknowledged
# 12      16V  Acknowledged
# 13      44V  Acknowledged
# 14      45V  Acknowledged
# 15      48H  Acknowledged
# 16      48V  Acknowledged
# 17      49H  Acknowledged
# 18      49V      Rejected
# 19      51V  Acknowledged
# 20      60H  Acknowledged
# 21      63H  Acknowledged
# 22      66H  Acknowledged
# 23      67H  Acknowledged
# 24      68H  Acknowledged
# 25      71V  Acknowledged
# 26      75H  Acknowledged
# 27      76H  Acknowledged
# 28      76V  Acknowledged
# 29      12H  Acknowledged
# 30      12V  Acknowledged
# 31     13aH  Acknowledged
# 32     13aV  Acknowledged
# 33     13bH  Acknowledged
# 34     13bV  Acknowledged
# 35   13.2.1  Acknowledged
# 36   13.2.2  Acknowledged
# 37  9.2.1-A  Acknowledged
# 38    9.2.2  Acknowledged
# 39    9.2.3  Acknowledged
# 40    9.2.5  Acknowledged
# 41  9.2.6-A  Acknowledged
# 42  9.2.6-B  Acknowledged
# 43    9.4.1  Acknowledged
# 44    9.4.2  Acknowledged
# 45   12.4.1  Acknowledged
# 46   12.4.3  Acknowledged
# 47   14.1.2  Acknowledged
# 48   18.1.4  Acknowledged
# 19V
# 4H
# 58H
# 61H
# 61V
# 69H
# 69V
# 70V
# 11H
# 11V
# 16V
# 2H
# 44V
# 45V
# 48H
# 48V
# 49H
# 49V
# 51V
# 60H
# 63H
# 66H
# 67H
# 68H
# 71V
# 75H
# 76H
# 76V
# 12H
# 29    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# C - DM Application
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       19V  Acknowledged
# 3       58H  Acknowledged
# 4       61H  Acknowledged
# 5       61V  Acknowledged
# 6       69H  Acknowledged
# 7       69V  Acknowledged
# 8       70V  Acknowledged
# 9        2H  Acknowledged
# 10      11H  Acknowledged
# 11      11V  Acknowledged
# 12      16V  Acknowledged
# 13      44V  Acknowledged
# 14      45V  Acknowledged
# 15      48H  Acknowledged
# 16      48V  Acknowledged
# 17      49H  Acknowledged
# 18      49V      Rejected
# 19      51V  Acknowledged
# 20      60H  Acknowledged
# 21      63H  Acknowledged
# 22      66H  Acknowledged
# 23      67H  Acknowledged
# 24      68H  Acknowledged
# 25      71V  Acknowledged
# 26      75H  Acknowledged
# 27      76H  Acknowledged
# 28      76V  Acknowledged
# 29      12H  Acknowledged
# 30      12V  Acknowledged
# 31     13aH  Acknowledged
# 32     13aV  Acknowledged
# 33     13bH  Acknowledged
# 34     13bV  Acknowledged
# 35   13.2.1  Acknowledged
# 36   13.2.2  Acknowledged
# 37  9.2.1-A  Acknowledged
# 38    9.2.2  Acknowledged
# 39    9.2.3  Acknowledged
# 40    9.2.5  Acknowledged
# 41  9.2.6-A  Acknowledged
# 42  9.2.6-B  Acknowledged
# 43    9.4.1  Acknowledged
# 44    9.4.2  Acknowledged
# 45   12.4.1  Acknowledged
# 46   12.4.3  Acknowledged
# 47   14.1.2  Acknowledged
# 48   18.1.4  Acknowledged
# 19V
# 4H
# 58H
# 61H
# 61V
# 69H
# 69V
# 70V
# 11H
# 11V
# 16V
# 2H
# 44V
# 45V
# 48H
# 48V
# 49H
# 49V
# 51V
# 60H
# 63H
# 66H
# 67H
# 68H
# 71V
# 75H
# 76H
# 76V
# 12H
# 29    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# D - Database
#      Req nr      Response
# 0       NaN           NaN
# 1        4H  Acknowledged
# 2       19V  Acknowledged
# 3       58H  Acknowledged
# 4       61H  Acknowledged
# 5       61V  Acknowledged
# 6       69H  Acknowledged
# 7       69V  Acknowledged
# 8       70V  Acknowledged
# 9        2H  Acknowledged
# 10      11H  Acknowledged
# 11      11V  Acknowledged
# 12      16V  Acknowledged
# 13      44V  Acknowledged
# 14      45V  Acknowledged
# 15      48H  Acknowledged
# 16      48V  Acknowledged
# 17      49H  Acknowledged
# 18      49V      Rejected
# 19      51V  Acknowledged
# 20      60H  Acknowledged
# 21      63H  Acknowledged
# 22      66H  Acknowledged
# 23      67H  Acknowledged
# 24      68H  Acknowledged
# 25      71V  Acknowledged
# 26      75H  Acknowledged
# 27      76H  Acknowledged
# 28      76V  Acknowledged
# 29      12H  Acknowledged
# 30      12V  Acknowledged
# 31     13aH  Acknowledged
# 32     13aV  Acknowledged
# 33     13bH  Acknowledged
# 34     13bV  Acknowledged
# 35   13.2.1  Acknowledged
# 36   13.2.2  Acknowledged
# 37  9.2.1-A  Acknowledged
# 38    9.2.2  Acknowledged
# 39    9.2.3  Acknowledged
# 40    9.2.5  Acknowledged
# 41  9.2.6-A  Acknowledged
# 42  9.2.6-B  Acknowledged
# 43    9.4.1  Acknowledged
# 44    9.4.2  Acknowledged
# 45   12.4.1  Acknowledged
# 46   12.4.3  Acknowledged
# 47   14.1.2  Acknowledged
# 48   18.1.4  Acknowledged
# 19V
# 4H
# 58H
# 61H
# 61V
# 69H
# 69V
# 70V
# 11H
# 11V
# 16V
# 2H
# 44V
# 45V
# 48H
# 48V
# 49H
# 49V
# 51V
# 60H
# 63H
# 66H
# 67H
# 68H
# 71V
# 75H
# 76H
# 76V
# 12H
# 29    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV
# GDPR-RS-EPS109-SME SOHO-V4.0 RELEASED -- AS Reviewed 18.04.2018.xlsx
# A - SME SOHO
#      Req nr      Response
# 0       NaN           NaN
# 1       11H  Acknowledged
# 2       11V  Acknowledged
# 3       12H  Acknowledged
# 4       12V  Acknowledged
# 5      13aH  Acknowledged
# 6      13aV  Acknowledged
# 7      13bH  Acknowledged
# 8      13bV  Acknowledged
# 9       44V  Acknowledged
# 10      45V  Acknowledged
# 11      51V  Acknowledged
# 12      57H  Acknowledged
# 13      57V  Acknowledged
# 14      63H  Acknowledged
# 15       2H  Acknowledged
# 16       4H  Acknowledged
# 17      15V  Acknowledged
# 18      16V  Acknowledged
# 19      53V     Completed
# 20      58H  Acknowledged
# 21      60H  Acknowledged
# 22      74V  Acknowledged
# 23      75H  Acknowledged
# 24      76H  Acknowledged
# 25      76V  Acknowledged
# 26      22V  Acknowledged
# 27      23V  Acknowledged
# 28      61H  Acknowledged
# 29      61V  Acknowledged
# 30  9.2.1-A  Acknowledged
# 31    9.2.2  Acknowledged
# 32    9.2.5  Acknowledged
# 33    9.4.1  Acknowledged
# 34   12.4.1  Acknowledged
# 35    9.2.3  Acknowledged
# 36  9.2.6-A  Acknowledged
# 37  9.2.6-B  Acknowledged
# 38    9.4.2  Acknowledged
# 39   12.4.3  Acknowledged
# 40   18.1.4  Acknowledged
# 41   13.2.1  Acknowledged
# 42   13.2.2  Acknowledged
# 43   14.1.2  Acknowledged
# 15V
# 22V
# 23V
# 53V
# 57H
# 57V
# 74V
# 4H
# 58H
# 61H
# 61V
# 11H
# 11V
# 16V
# 2H
# 44V
# 45V
# 51V
# 60H
# 63H
# 75H
# 76H
# 76V
# 12H
# 3    Acknowledged
# Name: Response, dtype: object
# 12V
# 13aH
# 13aV
# 13bH
# 13bV

# %%
for filename in os.listdir(os.getcwd()):
    output_writer = pd.ExcelWriter(OUTPUT_BASE_PATH + 'CONVERTED-SCA-' + filename[:14] + '.xlsx')

    df = pd.read_excel(filename, sheet_name=None)
    
    sheet_names = df.keys()
    sheets = sheet_names[4:-1]
    #print sheets

    for sh in sheets:
        #print sh
        if sh == u'PII Data Record': # this is a bug? Don't know why I need this.  For some reason the last sheet comes through.
            continue
        #new_rs_sheets.update({filename: dict({sh: convert_rs(df[sh], cookbook)})})
        out_df = convert_existing_sca_rs(df[sh], cookbook_sca)
        out_df.to_excel(output_writer,sh)
        
    output_writer.save()

# %%
out_df.loc[out_df['Req nr'] == 'EPSXXX-SCA9.2.2-Y', 'Response'] = 'AJB'

# %%
list(out_df.loc[out_df['Req nr'] == 'EPSXXX-SCA9.2.2-Y', 'Response'])[0]
# Out:
# 'AJB'

# %%
nan = ''

# %%
test_list = [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, u'Rejected', nan, u'Rejected', nan, nan, nan, nan, nan, nan, nan, u'Rejected', nan, nan, u'Rejected', nan, u'Acknowledged', nan, nan, nan, nan, nan, nan, nan, nan, u'Acknowledged', nan, nan, nan, u'Rejected', nan, u'Acknowledged', nan, nan, nan, nan]

# %%
len(test_list)
# Out:
# 104
